# %% [markdown]
# Importing Necessary Libraries For Data Preprocessing and Visualization

# %%
#It provides data structures and data analysis tools.
#It's commonly used to handle and manipulate tabular data.
import pandas as pd 


#It provides support for arrays, matrices, and mathematical functions
import numpy as np 


#It is used for creating visualizations and plots in Python.
import matplotlib.pyplot as plt


#Is is built  based on Matplotlib and provides additional functions
#to create more visually appealing statistical plots
import seaborn as sns

# %% [markdown]
# Reading The Dataset

# %%
# reading the dataset into a dataframe
df = pd.read_csv('../Dataset/employee_attrition_dataset.csv')

# %%
# Define the column names and descriptions
column_names = ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
                'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
                'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
                'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
                'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
                'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
                'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
                'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
                'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
                'YearsWithCurrManager']

descriptions = [
    """Employee's age""",
    """Does the employee leave the organization""",
    """Frequency of employees' business trips""",
    """Daily salary rate for employees""",
    """Office of employees""",
    """Distance from home in miles to work""",
    """Level of education achieved by staff""",
    """Employee's field of study""",
    """Total number of employees in the organization""",
    """A unique identifier for each employee record""",
    """Employee satisfaction with their working environment""",
    """Employee's Gender""",
    """Hourly rate for employees""",
    """Level of involvement required for the employee's job""",
    """Employee's level of work""",
    """The role of employees in the organization""",
    """Employee satisfaction with their work""",
    """Employee's marital status""",
    """Employee's monthly income""",
    """Monthly salary rate for employees""",
    """Number of companies the employee worked for""",
    """Whether the employee is over 18 years old""",
    """Do employees work overtime""",
    """Salary increase rate for employees""",
    """The performance rating of the employee""",
    """Employee satisfaction with their relationships""",
    """Standard working hours for employees""",
    """Employee stock option level""",
    """Total number of years the employee has worked""",
    """Number of times employees were taken to training in the last year""",
    """Employees' perception of their work-life balance""",
    """Number of years employees have been with the company""",
    """Number of years the employee has been in their current role""",
    """Number of years since employee's last promotion""",
    """Number of years an employee has been with their current manager"""
]

# Create a DataFrame with the column names and descriptions
data_info = pd.DataFrame({"Column_names": column_names, "Description": descriptions})

# Display the DataFrame
data_info
# Out:
#                 Column_names  \
# 0                        Age
# 1                  Attrition
# 2             BusinessTravel
# 3                  DailyRate
# 4                 Department
# 5           DistanceFromHome
# 6                  Education
# 7             EducationField
# 8              EmployeeCount
# 9             EmployeeNumber
# 10   EnvironmentSatisfaction
# 11                    Gender
# 12                HourlyRate
# 13            JobInvolvement
# 14                  JobLevel
# 15                   JobRole
# 16           JobSatisfaction
# 17             MaritalStatus
# 18             MonthlyIncome
# 19               MonthlyRate
# 20        NumCompaniesWorked
# 21                    Over18
# 22                  OverTime
# 23         PercentSalaryHike
# 24         PerformanceRating
# 25  RelationshipSatisfaction
# 26             StandardHours
# 27          StockOptionLevel
# 28         TotalWorkingYears
# 29     TrainingTimesLastYear
# 30           WorkLifeBalance
# ...

# %% [markdown]
# 1. Visulatizing Data
#
# 2. Finding Out Which Column is Less Impactfull
#
# 3. And Finally Removing The Less Impactfull Columns

# %%
# showing some information about the dataset and checking for the null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# To See How our Dataset Look Like

# %%
# seeing first 10 rows from our dataset
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
# showing last 10 rows from out dataset
df.tail(10)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1460   29        No      Travel_Rarely        468  Research & Development
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1464   26        No      Travel_Rarely       1167                   Sales
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1460                28          4        Medical              1
# ...

# %% [markdown]
# Showing The Number Of Unique Values That One column contains

# %%
df.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
# visualizing the data Marital Status Based On Employee Attrition
custom_palette = {'Yes': 'blue', 'No': 'lightblue'}
sns.countplot(x='MaritalStatus', hue='Attrition', data=df,palette=custom_palette)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('Marital Status based on Employee Attrition')
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.show()

# %%
# visualizing the data OverTime Based On Employee Attrition
sns.countplot(x='OverTime', hue='Attrition', data=df)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('OverTime based on Employee Attrition')
plt.xlabel('OverTime')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of  the values on X-axis
#
# EnvironmentSatisfaction
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High

# %%
# visualizing data EnvironmentSatisfaction based on Employee Attrition
custom_palette = {'Yes': 'lightblue', 'No': 'red'}
sns.countplot(x='EnvironmentSatisfaction', hue='Attrition', data=df,palette=custom_palette)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('EnvironmentSatisfaction based on Employee Attrition')
plt.xlabel('EnvironmentSatisfaction')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of the Numeric Numbers On X- Axis
#
# Education
#
# 1 'Below College'
#
# 2 'College'
#
# 3 'Bachelor'
#
# 4 'Master'
#
# 5 'Doctor'

# %%
# visualizing data EnvironmentSatisfaction based on Employee Attrition
sns.countplot(x='Education', hue='Attrition', data=df)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('Education based on Employee Attrition')
plt.xlabel('Education')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of the numeric values on X-axis
#
# JobInvolvement
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'

# %%
# visualizing data JobInvolvement based on Employee Attrition
sns.countplot(x='JobInvolvement', hue='Attrition', data=df,palette="Set1")
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('JobInvolvement based on Employee Attrition')
plt.xlabel('JobInvolvement')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of the numeric values on X-axis
#
# JobSatisfaction
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'

# %%
# visualizing data JobSatisfaction based on Employee Attrition
sns.countplot(x='JobSatisfaction', hue='Attrition', data=df)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('JobSatisfaction based on Employee Attrition')
plt.xlabel('JobSatisfaction')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of the numeric values on X-axis
#
# PerformanceRating
#
# 1 'Low'
#
# 2 'Good'
#
# 3 'Excellent'
#
# 4 'Outstanding'

# %%
# visualizing data PerformanceRating based on Employee Attrition
sns.countplot(x='PerformanceRating', hue='Attrition', data=df,palette='rocket')
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('PerformanceRating based on Employee Attrition')
plt.xlabel('PerformanceRating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of the numeric values on X-axis
#
# RelationshipSatisfaction
#
# 1 'Low'
#
# 2 'Medium'
#
# 3 'High'
#
# 4 'Very High'

# %%
# visualizing data RelationshipSatisfaction based on Employee Attrition
sns.countplot(x='RelationshipSatisfaction', hue='Attrition', data=df,palette="tab10")
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('RelationshipSatisfaction based on Employee Attrition')
plt.xlabel('RelationshipSatisfaction')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Meanings of the numeric values on X-axis
#
# WorkLifeBalance
#
# 1 'Bad'
#
# 2 'Good'
#
# 3 'Better'
#
# 4 'Best'

# %%
# visualizing data WorkLifeBalance based on Employee Attrition
custom_palette = {'Yes': 'red', 'No': 'blue'}
sns.countplot(x='WorkLifeBalance', hue='Attrition', data=df,palette=custom_palette)
fig = plt.gcf()
fig.set_size_inches(20,8)
plt.title('WorkLifeBalance based on Employee Attrition')
plt.xlabel('WorkLifeBalance')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# As Age Column has many unique values,
#
# we have visualize Age Column Based On Attrition Column,
#
# in a histogram plot

# %%
## Visualizing Age based on Employee Attrition
plt.figure(figsize=(20, 8))
sns.histplot(data=df, x="Age", hue="Attrition", element="bars", multiple="stack", fill=True,palette="rocket")
plt.title('Attrition Status by Age', fontsize=15)
plt.xlim([df['Age'].min(), df['Age'].max()]) 
plt.legend(title='Attrition', labels=['No', 'Yes'])
plt.show()

# %%
## Visualizing DistanceFromHome based on Employee Attrition
plt.figure(figsize=(20, 8))
sns.histplot(data=df, x="DistanceFromHome", hue="Attrition", element="bars", multiple="stack", fill=True)
plt.title('Attrition Status by DistanceFromHome', fontsize=15)
plt.xlim([df['DistanceFromHome'].min(), df['DistanceFromHome'].max()]) 
plt.legend(title='Attrition', labels=['No', 'Yes'])
plt.show()

# %%
## Visualizing TotalWorkingYears based on Employee Attrition
plt.figure(figsize=(20, 8))
sns.histplot(data=df, x="TotalWorkingYears", hue="Attrition", element="bars", multiple="stack", fill=True,palette="Set2")
plt.title('Attrition Status by TotalWorkingYears', fontsize=15)
plt.xlim([df['TotalWorkingYears'].min(), df['TotalWorkingYears'].max()]) 
plt.legend(title='Attrition', labels=['No', 'Yes'])
plt.show()

# %%
## Visualizing MonthlyRate based on Employee Attrition
plt.figure(figsize=(20, 8))
sns.histplot(data=df, x="MonthlyRate", hue="Attrition", element="bars", multiple="stack", fill=True,palette="Set2")
plt.title('Attrition Status by MonthlyRate', fontsize=15)
plt.xlim([df['MonthlyRate'].min(), df['MonthlyRate'].max()]) 
plt.legend(title='Attrition', labels=['No', 'Yes'])
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.histplot(data=df, x="EmployeeNumber", hue="Attrition", element="bars", multiple="stack", fill=True,palette="Set2")
plt.title('Attrition Status by EmployeeNumber', fontsize=15)
plt.xlim([df['EmployeeNumber'].min(), df['EmployeeNumber'].max()]) 
plt.legend(title='Attrition', labels=['No', 'Yes'])
plt.show()

# %% [markdown]
# After visualizing some columns based of Attrition
#
# We have a conclusion to remove some of the columns
#
# 1.EmployeeCount
#
# 2.EmployeeNumber
#
# 3.Over18
#
# 4.StandardHours
#
# 5.StockOptionLevel

# %%
## before removing the shape is
df.shape
# Out:
# (1470, 35)

# %%
df.drop(columns=['EmployeeCount','EmployeeNumber','Over18','StandardHours','StockOptionLevel'],inplace=True)

# %%
# after removing the shape is
df.shape
# Out:
# (1470, 30)

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 30 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %% [markdown]
# Now we have to convert the categorical value to numeric value
#
# Here Two types of categorical value can be there
#
# 1. categorical data with their ordinal relationship ( has a meaning of their order)
#
# 2. categorical data without their ordinal relationship (do not have meaning of their order)
#
# Now we have to findout the type-1 and type-2 categorical data in our dataset
#
# for type-1 we  used the label encoder to covert them into numeric value
#
# for type-2 wel used the one-hot encoder to covert them into numeric value
#
# type-1 categorical data in our dataset
#
# 1.Attrition
#
# 2.BussinessTravel
#
# 3.Department
#
# 4.EducationField
#
# 5.JobRole
#
# 6.MaritalStatus
#
# 7.OverTime
#
# type-2 categorical data in our dataset
#
# 1.Gender

# %%
#It is used for data preprocessing tasks like scaling, encoding
from sklearn import preprocessing

# %%
# Label Encoding
label_encoder = preprocessing.LabelEncoder()

df['attrition'] = label_encoder.fit_transform(df['Attrition'])
## printing the label mapping
label_mapping = dict(zip(df['attrition'], df['Attrition']))
## print in sorted order
print('For Attrition Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['businessTravel'] = label_encoder.fit_transform(df['BusinessTravel'])
## printing the label mapping
label_mapping = dict(zip(df['businessTravel'], df['BusinessTravel']))
## print in sorted order
print('For BusinessTravel Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['department'] = label_encoder.fit_transform(df['Department'])
## printing the label mapping
label_mapping = dict(zip(df['department'], df['Department']))
## print in sorted order
print('For Department Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['educationField'] = label_encoder.fit_transform(df['EducationField'])
## printing the label mapping
label_mapping = dict(zip(df['educationField'], df['EducationField']))
## print in sorted order
print('For EducationField Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['jobRole'] = label_encoder.fit_transform(df['JobRole'])
## printing the label mapping
label_mapping = dict(zip(df['jobRole'], df['JobRole']))
## print in sorted order
print('For JobRole Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['maritalStatus'] = label_encoder.fit_transform(df['MaritalStatus'])
## printing the label mapping
label_mapping = dict(zip(df['maritalStatus'], df['MaritalStatus']))
## print in sorted order
print('For MaritalStatus Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['overTime'] = label_encoder.fit_transform(df['OverTime'])
## printing the label mapping
label_mapping = dict(zip(df['overTime'], df['OverTime']))
## print in sorted order
print('For OverTime Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));
 #  Removing the  unnecessary and same meaning columns
df.drop(columns=['Attrition','BusinessTravel', 'Department', 'EducationField','JobRole', 'MaritalStatus','OverTime'],inplace=True)

# overview of the data after label encoding and removing the unnecessary columns
df.head(10)
# Out:
# For Attrition Column
# {0: 'No', 1: 'Yes'}
# For BusinessTravel Column
# {0: 'Non-Travel', 1: 'Travel_Frequently', 2: 'Travel_Rarely'}
# For Department Column
# {0: 'Human Resources', 1: 'Research & Development', 2: 'Sales'}
# For EducationField Column
# {0: 'Human Resources', 1: 'Life Sciences', 2: 'Marketing', 3: 'Medical', 4: 'Other', 5: 'Technical Degree'}
# For JobRole Column
# {0: 'Healthcare Representative', 1: 'Human Resources', 2: 'Laboratory Technician', 3: 'Manager', 4: 'Manufacturing Director', 5: 'Research Director', 6: 'Research Scientist', 7: 'Sales Executive', 8: 'Sales Representative'}
# For MaritalStatus Column
# {0: 'Divorced', 1: 'Married', 2: 'Single'}
# For OverTime Column
# {0: 'No', 1: 'Yes'}
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# ...

# %%
## implement oneHot Encoding using the dummies from pandas
dummies = pd.get_dummies(df['Gender'])
dummies
# Out:
#       Female   Male
# 0       True  False
# 1      False   True
# 2      False   True
# 3       True  False
# 4      False   True
# ...      ...    ...
# 1465   False   True
# 1466   False   True
# 1467   False   True
# 1468   False   True
# 1469   False   True
#
# [1470 rows x 2 columns]

# %%
df = pd.concat([df,dummies],axis=1)
df.head()
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
#
#    Gender  HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  ...  \
# 0  Female          94               3         2                4  ...
# 1    Male          61               2         2                2  ...
# 2    Male          92               2         1                3  ...
# 3  Female          56               3         1                3  ...
# 4    Male          40               3         1                2  ...
#
#    YearsWithCurrManager  attrition  businessTravel  department  \
# ...

# %%
## again performing label endcoding to Female and Male column
df['female'] = label_encoder.fit_transform(df['Female'])
## printing the label mapping
label_mapping = dict(zip(df['female'], df['Female']))
## print in sorted order
print('For Female Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));

df['male'] = label_encoder.fit_transform(df['Male'])
## printing the label mapping
label_mapping = dict(zip(df['male'], df['Male']))
## print in sorted order
print('For Male Column')
print(dict(sorted(label_mapping.items(), key=lambda item: item[1])));
df.drop(columns=['Male','Female','Gender'],inplace=True)
# Out:
# For Female Column
# {0: False, 1: True}
# For Male Column
# {0: False, 1: True}

# %%
df.head(10)
# Out:
#    Age  DailyRate  DistanceFromHome  Education  EnvironmentSatisfaction  \
# 0   41       1102                 1          2                        2
# 1   49        279                 8          1                        3
# 2   37       1373                 2          2                        4
# 3   33       1392                 3          4                        4
# 4   27        591                 2          1                        1
# 5   32       1005                 2          2                        4
# 6   59       1324                 3          3                        3
# 7   30       1358                24          1                        4
# 8   38        216                23          3                        4
# 9   36       1299                27          3                        3
#
#    HourlyRate  JobInvolvement  JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# 0          94               3         2                4           5993  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   DailyRate                 1470 non-null   int64
#  2   DistanceFromHome          1470 non-null   int64
#  3   Education                 1470 non-null   int64
#  4   EnvironmentSatisfaction   1470 non-null   int64
#  5   HourlyRate                1470 non-null   int64
#  6   JobInvolvement            1470 non-null   int64
#  7   JobLevel                  1470 non-null   int64
#  8   JobSatisfaction           1470 non-null   int64
#  9   MonthlyIncome             1470 non-null   int64
#  10  MonthlyRate               1470 non-null   int64
#  11  NumCompaniesWorked        1470 non-null   int64
#  12  PercentSalaryHike         1470 non-null   int64
#  13  PerformanceRating         1470 non-null   int64
# ...

# %%
# Plot feature correlations with target variable in our case attrition
plt.figure(figsize=(35,15))
corr=abs(df.corr())
sns.heatmap(corr,annot=True,linewidth=1,cmap="Reds")
plt.figure(figsize=(35,15))
plt.plot(corr["attrition"].sort_values(ascending=False)[1:],label="Correlation")
plt.ylabel("Correlation")
plt.xlabel("Feature")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df.nunique()
# Out:
# Age                           43
# DailyRate                    886
# DistanceFromHome              29
# Education                      5
# EnvironmentSatisfaction        4
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobSatisfaction                4
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# TotalWorkingYears             40
# TrainingTimesLastYear          7
# WorkLifeBalance                4
# YearsAtCompany                37
# YearsInCurrentRole            19
# YearsSinceLastPromotion       16
# YearsWithCurrManager          18
# attrition                      2
# businessTravel                 3
# department                     3
# educationField                 6
# jobRole                        9
# maritalStatus                  3
# ...

# %%
# used to split a dataset into training and testing subsets.
from sklearn.model_selection import train_test_split

# create the target vector
y = df['attrition']

# drop the 'attrition' column from the DataFrame to create the feature matrix
X = df.drop('attrition', axis=1)

"""
  splitting the data set into train and test data  where 70% of the data used
  for train the model and 30% data is used for test the model
"""
# split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.45, stratify=y, random_state=42)

# check shape
print('x_train: ', X_train.shape)
print('x_test: ', X_test.shape)
print('y_train: ', y_train.shape)
print('y_test: ', y_test.shape)
# Out:
# x_train:  (808, 30)
# x_test:  (662, 30)
# y_train:  (808,)
# y_test:  (662,)

# %%
# Make the Imbalance Data into Balanced Data
from imblearn.over_sampling import SMOTE

# Create a SMOTE object
smote = SMOTE(random_state=42)

# Fit the SMOTE object to the training data and oversample the minority class
X_train, y_train = smote.fit_resample(X_train, y_train)
df_train = pd.concat([X_train, y_train], axis=1)

# %%
## after fixing the imbalances over stroke column
# Map targets to meaningful statements
classes = {
    'Attritioned': 0,
    'Not Attritioned': 1
}
# Find the number of patients with/without heart disease
class_pop = [len(y_train == _class) for _class in classes.values()]
fig, ax = plt.subplots(figsize=(8, 8)) 
# Drawing a donut chart
plt.title('Class Population Distribution')
plt.pie(
    x=class_pop,
    labels=classes.keys(),
    autopct='%.1f%%',
    explode=[0.02, 0],
    pctdistance=0.85
)
center_circle = plt.Circle((0, 0), 0.8, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
# Set the background to white
fig.patch.set_facecolor('white')
plt.show()
